# %%
import polars as pl

# %%
import os
from pathlib import Path

# Use relative path from this notebook's location
notebook_dir = Path(os.path.abspath(""))
data_path = (
    notebook_dir / "data" / "PXD061065" / "20250204_112949_gbm_sc_full_fasta_19.4_Report.tsv"
)
data = pl.read_csv(str(data_path), separator="\t")

# %%
columns = data.columns
quantity_columns = []
for col in columns:
    if "Quantity" in col:
        quantity_columns.append(col)
genes_col = "PG.Genes"

# %%
data = data.select(genes_col, *quantity_columns)
